# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
import csv
d= pd.read_csv("20130data.csv")
print (d)
da = pd.read_csv(("20130data.csv"), sep="[;]", engine='python')
print (da)
x=[row[0] for row in (da)]
print (x)
plt.plot(['Angle'],['Intensity'])
# Out:
#        10.00328257;209
# 0      10.00984771;209
# 1      10.01641285;203
# 2      10.02297799;194
# 3      10.02954314;231
# 4      10.03610828;219
# ...                ...
# 13706   99.99167519;66
# 13707   99.99824033;86
# 13708   100.0048055;66
# 13709   100.0113706;85
# 13710   100.0179358;78
#
# [13711 rows x 1 columns]
#        10.00328257  209
# 0        10.009848  209
# 1        10.016413  203
# 2        10.022978  194
# 3        10.029543  231
# 4        10.036108  219
# ...            ...  ...
# 13706    99.991675   66
# 13707    99.998240   86
# 13708   100.004806   66
# 13709   100.011371   85
# 13710   100.017936   78
#
# [13711 rows x 2 columns]
# ['1', '2']
